# %%
# Load the "autoreload" extension
# %load_ext autoreload

# always reload modules marked with "%aimport"
# %autoreload 1

# %%
import gzip
import json
import pandas as pd

# %%
df = pd.read_json('AMAZON_FASHION.json.gz', lines=True, compression='gzip')
df.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  reviewerName  \
# 0        5      True  10 20, 2014  A1D4G1SNUZWQOT  7106116521         Tracy
# 1        2      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521     Sonja Lau
# 2        4     False  08 25, 2014  A2MWC41EW7XL15  7106116521      Kathleen
# 3        2      True  08 24, 2014  A2UH2QQ275NV45  7106116521   Jodi Stoner
# 4        3     False  07 27, 2014   A89F3LQADZBS5  7106116521  Alexander D.
#
#                                           reviewText  \
# 0                             Exactly what I needed.
# 1  I agree with the other review, the opening is ...
# 2  Love these... I am going to order another pack...
# 3                                too tiny an opening
# 4                                               Okay
#
#                                              summary  unixReviewTime  vote  \
# 0                             perfect replacements!!      1413763200   NaN
# 1  I agree with the other review, the opening is ...      1411862400   3.0
# 2                                My New 'Friends' !!      1408924800   NaN
# 3                                          Two Stars      1408838400   NaN
# 4                                        Three Stars      1406419200   NaN
#
#   style image
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# 3   NaN   NaN
# 4   NaN   NaN

# %%
df.shape
# Out:
# (883636, 12)

# %%
# remove duplicate reviews
df = df[~df.astype(str).duplicated(df.columns.drop(['asin','vote','style']))]
df.shape
# Out:
# (853805, 12)

# %%
# drop rows with nan value for review
df = df.dropna(subset=['reviewText'])
df.shape
# Out:
# (852636, 12)

# %%
# pd.set_option('display.max_colwidth', None)

# %% [markdown]
# <h1>Text Wrangling & Preprocessing</h1>

# %%
import numpy as np
# %aimport preprocessing
from preprocessing import text_preprocessing
from preprocessing import apply_preprocessing
import time

# %%
# from multiprocessing import Pool

# def parallelize_dataframe(df, func, n_cores=8):
#     '''parallel processing using multiple cores'''
#     if __name__ ==  '__main__':
#         df_split = np.array_split(df, n_cores)
#         pool = Pool(n_cores, maxtasksperchild=10000)
#         output = pool.imap(func, df_split)
#         pool.close()
#         pool.join()
#         return pd.concat(output)
#     else:
#         print('error')

# %%
# df['reviewText'] = df['reviewText'].astype(str)
# df = parallelize_dataframe(df, apply_preprocessing)

# %%
from joblib import Parallel, delayed
from tqdm import tqdm

# n_jobs is the number of parallel jobs
r = Parallel(n_jobs=8)(delayed(text_preprocessing)(review) for review in tqdm(df['reviewText']))
# Out:
#   0%|▏                                                                        | 2760/852636 [01:08<1:47:05, 132.26it/s]C:\Users\Billy\anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# 100%|████████████████████████████████████████████████████████████████████████| 852636/852636 [2:56:00<00:00, 80.74it/s]

# %%
reviews, words = zip(*r)
df['reviewClean_sw'] = reviews
df['noun_adjective'] = words

df.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  reviewerName  \
# 0        5      True  10 20, 2014  A1D4G1SNUZWQOT  7106116521         Tracy
# 1        2      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521     Sonja Lau
# 2        4     False  08 25, 2014  A2MWC41EW7XL15  7106116521      Kathleen
# 3        2      True  08 24, 2014  A2UH2QQ275NV45  7106116521   Jodi Stoner
# 4        3     False  07 27, 2014   A89F3LQADZBS5  7106116521  Alexander D.
#
#                                           reviewText  \
# 0                             Exactly what I needed.
# 1  I agree with the other review, the opening is ...
# 2  Love these... I am going to order another pack...
# 3                                too tiny an opening
# 4                                               Okay
#
#                                              summary  unixReviewTime  vote  \
# 0                             perfect replacements!!      1413763200   NaN
# 1  I agree with the other review, the opening is ...      1411862400   3.0
# 2                                My New 'Friends' !!      1408924800   NaN
# 3                                          Two Stars      1408838400   NaN
# 4                                        Three Stars      1406419200   NaN
#
#   style image                                     reviewClean_sw  \
# 0   NaN   NaN                        [exactly, what, i, need, .]
# 1   NaN   NaN  [i, agree, with, the, other, review, ,, the, o...
# 2   NaN   NaN  [love, these, ..., i, be, go, to, order, anoth...
# 3   NaN   NaN                           [too, tiny, an, opening]
# 4   NaN   NaN                                             [okay]
#
#                                       noun_adjective
# 0                                                 []
# 1  [other, review, opening, small, hook, expensiv...
# 2  [pack, work, someone, back, earring, fish, hoo...
# 3                                    [tiny, opening]
# 4                                                 []

# %%
import string
from spacy.lang.en.stop_words import STOP_WORDS

punctuations = list(string.punctuation)

def remove_stop_punc(tokens):
    reviewClean = []
    for token in tokens:
        if token not in STOP_WORDS and token not in punctuations:
            reviewClean.append(token)
        if token in ['no', 'not']:
            reviewClean.append(token)
        else:
            pass
    return reviewClean

# %%
from tqdm import tqdm

tqdm.pandas()
df['reviewClean'] = df['reviewClean_sw'].progress_apply(remove_stop_punc)

df.head()
# Out:
# C:\Users\Billy\anaconda3\lib\site-packages\tqdm\std.py:699: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# 100%|██████████████████████████████████████████████████████████████████████| 852589/852589 [00:08<00:00, 104088.70it/s]
#    overall  verified reviewTime      reviewerID        asin  reviewerName  \
# 0        5      True 2014-10-20  A1D4G1SNUZWQOT  7106116521         Tracy
# 1        2      True 2014-09-28  A3DDWDH9PX2YX2  7106116521     Sonja Lau
# 2        4     False 2014-08-25  A2MWC41EW7XL15  7106116521      Kathleen
# 3        2      True 2014-08-24  A2UH2QQ275NV45  7106116521   Jodi Stoner
# 4        3     False 2014-07-27   A89F3LQADZBS5  7106116521  Alexander D.
#
#                                           reviewText  \
# 0                             Exactly what I needed.
# 1  I agree with the other review, the opening is ...
# 2  Love these... I am going to order another pack...
# 3                                too tiny an opening
# 4                                               Okay
#
#                                              summary  unixReviewTime  vote  \
# 0                             perfect replacements!!      1413763200   NaN
# 1  I agree with the other review, the opening is ...      1411862400   3.0
# 2                                My New 'Friends' !!      1408924800   NaN
# 3                                          Two Stars      1408838400   NaN
# 4                                        Three Stars      1406419200   NaN
#
#   style image                                     reviewClean_sw  \
# 0   NaN   NaN                        [exactly, what, i, need, .]
# 1   NaN   NaN  [i, agree, with, the, other, review, ,, the, o...
# 2   NaN   NaN  [love, these, ..., i, be, go, to, order, anoth...
# 3   NaN   NaN                           [too, tiny, an, opening]
# 4   NaN   NaN                                             [okay]
#
#                                       noun_adjective  \
# 0                                                 []
# 1  [other, review, opening, small, hook, expensiv...
# 2  [pack, work, someone, back, earring, fish, hoo...
# 3                                    [tiny, opening]
# 4                                                 []
#
#                                          reviewClean  \
# 0                                    [exactly, need]
# 1  [agree, review, opening, small, bend, hook, ex...
# 2  [love, ..., order, pack, work, include, lose, ...
# 3                                    [tiny, opening]
# 4                                             [okay]
#
#                                             removeNo  reviewLength sentiment  \
# 0                                 [exactly, need, .]             5  Positive
# 1  [agree, review, ,, opening, small, ., bend, ho...            52  Negative
# 2  [love, ..., order, pack, work, ;, (, include, ...            54  Positive
# 3                                    [tiny, opening]             4  Negative
# 4                                             [okay]             1   Neutral
#
#    year
# 0  2014
# 1  2014
# 2  2014
# 3  2014
# 4  2014

# %%
# drop rows with empty lists for tokenized reviews
df = df[df.reviewClean_sw.str.len() != 0]

# %%
df.shape
# Out:
# (852589, 19)

# %%
df.to_csv('data_wrangling.csv', index=False)

# %% [markdown]
# <h1>EDA on Text Data</h1>

# %%
products = pd.read_json('meta_AMAZON_FASHION.json.gz', lines=True, compression='gzip')
products.head()
# Out:
#   category tech1                                        description fit  \
# 0       []                                                       []
# 1       []                                                       []
# 2       []        [Educating the next generation in the responsi...
# 3       []        [Envirosax Greengrocer - a range of plain colo...
# 4       []                                                       []
#
#                                                title also_buy  \
# 0                           Dante's Peak - Laserdisc       []
# 1  Milliongadgets(TM) Earring Safety Backs For Fi...       []
# 2            Envirosax Kids Series Jessie &amp; Lulu       []
# 3           Envirosax Greengrocer Series Bag 7 Guava       []
# 4  Blessed by Pope Benedetto XVI Our Lady of Guad...       []
#
#                                                image tech2           brand  \
# 0                                                 []
# 1  [https://images-na.ssl-images-amazon.com/image...
# 2                                                 []             Envirosax
# 3                                                 []             Envirosax
# 4                                                 []        Gifts by Lulee
#
#                                              feature  \
# 0  [<span class="a-text-bold">Package Dimensions:...
# 1  [<span class="a-text-bold">ASIN:\n            ...
# 2  [<span class="a-text-bold">Product Dimensions:...
# 3  [<span class="a-text-bold">Product Dimensions:...
# 4  [<span class="a-text-bold">Package Dimensions:...
#
#                                         rank also_view details  \
# 0  16,714,561 in Clothing, Shoes & Jewelry (        []      {}
# 1   2,081,098 in Clothing, Shoes & Jewelry (        []      {}
# 2  25,698,912 in Clothing, Shoes & Jewelry (        []      {}
# 3  25,850,143 in Clothing, Shoes & Jewelry (        []      {}
# 4  19,411,377 in Clothing, Shoes & Jewelry (        []      {}
#
#                                             main_cat similar_item  \
# 0  <img src="https://images-na.ssl-images-amazon....
# 1  <img src="https://images-na.ssl-images-amazon....
# 2  <img src="https://images-na.ssl-images-amazon....
# 3  <img src="https://images-na.ssl-images-amazon....
# 4  <img src="https://images-na.ssl-images-amazon....
#
#                                                 date price        asin
# 0  <div class="a-fixed-left-grid a-spacing-none">...        630456984X
# 1                                           fishhook        7106116521
# 2  <div class="a-fixed-left-grid a-spacing-none">...        8037200124
# 3  <div class="a-fixed-left-grid a-spacing-none">...        8037200221
# 4  <div class="a-fixed-left-grid a-spacing-none">...        8279996567

# %%
products.shape
# Out:
# (186627, 18)

# %%
# remove duplciate products
products = products[~products.astype(str).duplicated()]
products.shape
# Out:
# (186184, 18)

# %%
def remove_no(text):
    '''remove 'no' and 'not' from text'''
    return [word for word in text if word not in ['no', 'not']]

# %%
# remove no and not for text visualization
df['removeNo'] = df['reviewClean'].apply(remove_no)
df.head()
# Out:
#    overall  verified reviewTime      reviewerID        asin  reviewerName  \
# 0        5      True 2014-10-20  A1D4G1SNUZWQOT  7106116521         Tracy
# 1        2      True 2014-09-28  A3DDWDH9PX2YX2  7106116521     Sonja Lau
# 2        4     False 2014-08-25  A2MWC41EW7XL15  7106116521      Kathleen
# 3        2      True 2014-08-24  A2UH2QQ275NV45  7106116521   Jodi Stoner
# 4        3     False 2014-07-27   A89F3LQADZBS5  7106116521  Alexander D.
#
#                                           reviewText  \
# 0                             Exactly what I needed.
# 1  I agree with the other review, the opening is ...
# 2  Love these... I am going to order another pack...
# 3                                too tiny an opening
# 4                                               Okay
#
#                                              summary  unixReviewTime  vote  \
# 0                             perfect replacements!!      1413763200   NaN
# 1  I agree with the other review, the opening is ...      1411862400   3.0
# 2                                My New 'Friends' !!      1408924800   NaN
# 3                                          Two Stars      1408838400   NaN
# 4                                        Three Stars      1406419200   NaN
#
#   style image                                     reviewClean_sw  \
# 0   NaN   NaN                        [exactly, what, i, need, .]
# 1   NaN   NaN  [i, agree, with, the, other, review, ,, the, o...
# 2   NaN   NaN  [love, these, ..., i, be, go, to, order, anoth...
# 3   NaN   NaN                           [too, tiny, an, opening]
# 4   NaN   NaN                                             [okay]
#
#                                       noun_adjective  \
# 0                                                 []
# 1  [other, review, opening, small, hook, expensiv...
# 2  [pack, work, someone, back, earring, fish, hoo...
# 3                                    [tiny, opening]
# 4                                                 []
#
#                                          reviewClean  \
# 0                                    [exactly, need]
# 1  [agree, review, opening, small, bend, hook, ex...
# 2  [love, ..., order, pack, work, include, lose, ...
# 3                                    [tiny, opening]
# 4                                             [okay]
#
#                                             removeNo  reviewLength sentiment  \
# 0                                    [exactly, need]             5  Positive
# 1  [agree, review, opening, small, bend, hook, ex...            52  Negative
# 2  [love, ..., order, pack, work, include, lose, ...            54  Positive
# 3                                    [tiny, opening]             4  Negative
# 4                                             [okay]             1   Neutral
#
#    year
# 0  2014
# 1  2014
# 2  2014
# 3  2014
# 4  2014

# %% [markdown]
# **Review Word Clouds**

# %%
# group by products and combine reviews
df_grouped=df[['asin','removeNo']].groupby('asin').sum()
df_grouped.head()
# Out:
#                                                      removeNo
# asin
# 0764443682  [group, excellent, job, vbs, hesitate, purchas...
# 1291691480    [buy, brother, love, sooooo, picky, like, good]
# 1940280001  [book, include, great, routine, great, perform...
# 1940735033  [receive, review, copy, eric, endersons, ash, ...
# 1940967805  [aether, empire, series, comic, book, good, cr...

# %%
def convert_list_to_string(org_list, seperator=' '):
    """ Convert list to string, by joining all item in list with given separator.
        Returns the concatenated string """
    return seperator.join(org_list)

# %%
# convert processed reviews from lists to strings for count vectorizer
df_grouped['removeNo'] = df_grouped['removeNo'].apply(convert_list_to_string)
df_grouped.head()
# Out:
#                                                      removeNo
# asin
# 0764443682  group excellent job vbs hesitate purchase item...
# 1291691480            buy brother love sooooo picky like good
# 1940280001  book include great routine great performer sit...
# 1940735033  receive review copy eric endersons ash ashe or...
# 1940967805  aether empire series comic book good creative ...

# %%
# get indices for the top 5 products with longest reviews
indices = df_grouped['removeNo'].str.split().str.len().nlargest(n=5, keep='all').index
wordcloud = df_grouped.loc[indices]
wordcloud
# Out:
#                                                      removeNo
# asin
# B000KPIHQ4  good price good product howver generic need or...
# B00I0VHS10  amazing fit love quality great gym yoga super ...
# B00RLSCLJM  reason buy 300 dollar ring ring build like tan...
# B005N7YWX6  pick bellaband wife 7 week pretty wear day blo...
# B00GXE331K  order check quality practicality stainless ste...

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer()
count_vector = cv.fit_transform(wordcloud['removeNo'])

# %%
# document term matrix for the top 5 products
df_dtm = pd.DataFrame(count_vector.toarray(), columns=cv.get_feature_names())
df_dtm.index = wordcloud.index.map(products.set_index('asin')['title'])
df_dtm.head()
# Out:
#                                                     00  000  007  02  0493  \
# asin
# Powerstep Pinnacle Orthotic Shoe Insoles            25    2    0   0     0
# 90 Degree By Reflex Power Flex Yoga Capri &ndas...   5    0    0   2     0
# MJ Metals Jewelry 2mm to 10mm White Tungsten Ca...   9    2    0   0     0
# Ingrid &amp; Isabel Women's Maternity Everyday ...   3    0    0   0     0
# Best RFID Blocking Card Holder Case for Men and...   2    0    1   0     1
#
#                                                     05  0520252   10  100  \
# asin
# Powerstep Pinnacle Orthotic Shoe Insoles             0        0  121   16
# 90 Degree By Reflex Power Flex Yoga Capri &ndas...   0        0   68   34
# MJ Metals Jewelry 2mm to 10mm White Tungsten Ca...   0        0   60   24
# Ingrid &amp; Isabel Women's Maternity Everyday ...   0        0   57   10
# Best RFID Blocking Card Holder Case for Men and...   1        1   18   12
#
#                                                     1000  ...  zipper  \
# asin                                                      ...
# Powerstep Pinnacle Orthotic Shoe Insoles               0  ...       0
# 90 Degree By Reflex Power Flex Yoga Capri &ndas...     0  ...       3
# MJ Metals Jewelry 2mm to 10mm White Tungsten Ca...     3  ...       0
# Ingrid &amp; Isabel Women's Maternity Everyday ...     0  ...      86
# Best RFID Blocking Card Holder Case for Men and...     0  ...       0
#
#                                                     zippered  zipping  zippo  \
# asin
# Powerstep Pinnacle Orthotic Shoe Insoles                   0        0      0
# 90 Degree By Reflex Power Flex Yoga Capri &ndas...         0        0      0
# MJ Metals Jewelry 2mm to 10mm White Tungsten Ca...         0        0      0
# Ingrid &amp; Isabel Women's Maternity Everyday ...         3        1      0
# Best RFID Blocking Card Holder Case for Men and...         1        0      5
#
#                                                     zippy  zirconia  zobha  \
# asin
# Powerstep Pinnacle Orthotic Shoe Insoles                0         0      0
# 90 Degree By Reflex Power Flex Yoga Capri &ndas...      0         0      1
# MJ Metals Jewelry 2mm to 10mm White Tungsten Ca...      1         2      0
# Ingrid &amp; Isabel Women's Maternity Everyday ...      0         0      0
# Best RFID Blocking Card Holder Case for Men and...      0         0      0
#
#                                                     zoo  zumba  zumbathon
# asin
# Powerstep Pinnacle Orthotic Shoe Insoles              0      4          0
# 90 Degree By Reflex Power Flex Yoga Capri &ndas...    0     10          1
# MJ Metals Jewelry 2mm to 10mm White Tungsten Ca...    0      0          0
# Ingrid &amp; Isabel Women's Maternity Everyday ...    1      2          0
# Best RFID Blocking Card Holder Case for Men and...    1      0          0
#
# [5 rows x 8234 columns]

# %%
from wordcloud import WordCloud
from textwrap import wrap
import matplotlib.pyplot as plt

# Function for generating word clouds
def generate_wordcloud(data, title):
  wc = WordCloud(width=400, height=330, max_words=150, colormap="Dark2").generate_from_frequencies(data)
  plt.figure(figsize=(10,8))
  plt.imshow(wc, interpolation='bilinear')
  plt.axis('off')
  plt.title('\n'.join(wrap(title,60)), fontsize=13)
  plt.show()

# %%
# Transposing document term matrix
df_dtm=df_dtm.transpose()
df_dtm.head()
# Out:
# asin  Powerstep Pinnacle Orthotic Shoe Insoles  \
# 00                                          25
# 000                                          2
# 007                                          0
# 02                                           0
# 0493                                         0
#
# asin  90 Degree By Reflex Power Flex Yoga Capri &ndash; Cationic Heather Activewear Pants  \
# 00                                                    5
# 000                                                   0
# 007                                                   0
# 02                                                    2
# 0493                                                  0
#
# asin  MJ Metals Jewelry 2mm to 10mm White Tungsten Carbide Mirror Polished Classic Wedding Ring  \
# 00                                                    9
# 000                                                   2
# 007                                                   0
# 02                                                    0
# 0493                                                  0
#
# asin  Ingrid &amp; Isabel Women's Maternity Everyday Bellaband  \
# 00                                                    3
# 000                                                   0
# 007                                                   0
# 02                                                    0
# 0493                                                  0
#
# asin  Best RFID Blocking Card Holder Case for Men and Women Slim Stainless Steel Metal Wallet
# 00                                                    2
# 000                                                   0
# 007                                                   1
# 02                                                    0
# 0493                                                  1

# %%
# Plotting word cloud for each product
for product in df_dtm.columns:
    generate_wordcloud(df_dtm[product].sort_values(ascending=False), product)

# %% [markdown]
# **Frequencies of Words**

# %%
from collections import Counter
counts = Counter(df['removeNo'].explode()).most_common(20)
counts = pd.DataFrame(counts, columns=['word','frequency'])
counts.head()
# Out:
#    word  frequency
# 0   fit     211514
# 1  love     204120
# 2  like     158758
# 3  look     156866
# 4  size     155114

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 5))
sns.barplot(x='word', y='frequency', data=counts)
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# **Review Word Count Distribution**

# %%
# add a column for review length to the dataframe
df['reviewLength'] = df['reviewClean_sw'].str.len()
df.head()
# Out:
#    overall  verified reviewTime      reviewerID        asin  reviewerName  \
# 0        5      True 2014-10-20  A1D4G1SNUZWQOT  7106116521         Tracy
# 1        2      True 2014-09-28  A3DDWDH9PX2YX2  7106116521     Sonja Lau
# 2        4     False 2014-08-25  A2MWC41EW7XL15  7106116521      Kathleen
# 3        2      True 2014-08-24  A2UH2QQ275NV45  7106116521   Jodi Stoner
# 4        3     False 2014-07-27   A89F3LQADZBS5  7106116521  Alexander D.
#
#                                           reviewText  \
# 0                             Exactly what I needed.
# 1  I agree with the other review, the opening is ...
# 2  Love these... I am going to order another pack...
# 3                                too tiny an opening
# 4                                               Okay
#
#                                              summary  unixReviewTime  vote  \
# 0                             perfect replacements!!      1413763200   NaN
# 1  I agree with the other review, the opening is ...      1411862400   3.0
# 2                                My New 'Friends' !!      1408924800   NaN
# 3                                          Two Stars      1408838400   NaN
# 4                                        Three Stars      1406419200   NaN
#
#   style image                                     reviewClean_sw  \
# 0   NaN   NaN                        [exactly, what, i, need, .]
# 1   NaN   NaN  [i, agree, with, the, other, review, ,, the, o...
# 2   NaN   NaN  [love, these, ..., i, be, go, to, order, anoth...
# 3   NaN   NaN                           [too, tiny, an, opening]
# 4   NaN   NaN                                             [okay]
#
#                                       noun_adjective  \
# 0                                                 []
# 1  [other, review, opening, small, hook, expensiv...
# 2  [pack, work, someone, back, earring, fish, hoo...
# 3                                    [tiny, opening]
# 4                                                 []
#
#                                          reviewClean  \
# 0                                    [exactly, need]
# 1  [agree, review, opening, small, bend, hook, ex...
# 2  [love, ..., order, pack, work, include, lose, ...
# 3                                    [tiny, opening]
# 4                                             [okay]
#
#                                             removeNo  reviewLength sentiment  \
# 0                                    [exactly, need]             5  Positive
# 1  [agree, review, opening, small, bend, hook, ex...            52  Negative
# 2  [love, ..., order, pack, work, include, lose, ...            54  Positive
# 3                                    [tiny, opening]             4  Negative
# 4                                             [okay]             1   Neutral
#
#    year
# 0  2014
# 1  2014
# 2  2014
# 3  2014
# 4  2014

# %%
df['reviewLength'].describe()
# Out:
# count    852589.000000
# mean         32.629071
# std          43.806376
# min           1.000000
# 25%           8.000000
# 50%          20.000000
# 75%          40.000000
# max        2232.000000
# Name: reviewLength, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=df, x='reviewLength', binwidth=50)
plt.yscale('log')
plt.xlabel('Review Word Count')
plt.title('Review Length Distribution')
plt.xticks(range(0,2300,100))
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=df[df.reviewLength <= 100], x='reviewLength', binwidth=5)
plt.xlabel('Review Word Count')
plt.title('Review Length Distribution')
plt.xticks(range(0,100,10))
plt.show()

# %% [markdown]
# **Review Sentiment Distribution**

# %%
# map the reviews positive, neutral, negative according to the rating
df['sentiment'] = df['overall'].map({5: 'Positive', 4: 'Positive', 3: 'Neutral', 2: 'Negative', 1: 'Negative'})
df['reviewTime'] = pd.to_datetime(df['reviewTime'])
df['year'] = df['reviewTime'].dt.year
df.head()
# Out:
#    overall  verified reviewTime      reviewerID        asin  reviewerName  \
# 0        5      True 2014-10-20  A1D4G1SNUZWQOT  7106116521         Tracy
# 1        2      True 2014-09-28  A3DDWDH9PX2YX2  7106116521     Sonja Lau
# 2        4     False 2014-08-25  A2MWC41EW7XL15  7106116521      Kathleen
# 3        2      True 2014-08-24  A2UH2QQ275NV45  7106116521   Jodi Stoner
# 4        3     False 2014-07-27   A89F3LQADZBS5  7106116521  Alexander D.
#
#                                           reviewText  \
# 0                             Exactly what I needed.
# 1  I agree with the other review, the opening is ...
# 2  Love these... I am going to order another pack...
# 3                                too tiny an opening
# 4                                               Okay
#
#                                              summary  unixReviewTime  vote  \
# 0                             perfect replacements!!      1413763200   NaN
# 1  I agree with the other review, the opening is ...      1411862400   3.0
# 2                                My New 'Friends' !!      1408924800   NaN
# 3                                          Two Stars      1408838400   NaN
# 4                                        Three Stars      1406419200   NaN
#
#   style image                                     reviewClean_sw  \
# 0   NaN   NaN                        [exactly, what, i, need, .]
# 1   NaN   NaN  [i, agree, with, the, other, review, ,, the, o...
# 2   NaN   NaN  [love, these, ..., i, be, go, to, order, anoth...
# 3   NaN   NaN                           [too, tiny, an, opening]
# 4   NaN   NaN                                             [okay]
#
#                                       noun_adjective  \
# 0                                                 []
# 1  [other, review, opening, small, hook, expensiv...
# 2  [pack, work, someone, back, earring, fish, hoo...
# 3                                    [tiny, opening]
# 4                                                 []
#
#                                          reviewClean  \
# 0                                    [exactly, need]
# 1  [agree, review, opening, small, bend, hook, ex...
# 2  [love, ..., order, pack, work, include, lose, ...
# 3                                    [tiny, opening]
# 4                                             [okay]
#
#                                             removeNo  reviewLength sentiment  \
# 0                                    [exactly, need]             5  Positive
# 1  [agree, review, opening, small, bend, hook, ex...            52  Negative
# 2  [love, ..., order, pack, work, include, lose, ...            54  Positive
# 3                                    [tiny, opening]             4  Negative
# 4                                             [okay]             1   Neutral
#
#    year
# 0  2014
# 1  2014
# 2  2014
# 3  2014
# 4  2014

# %%
def pie_chart(df, year):
    df_year = df[df['year'] == year]
    
    # Declare a figure with a custom size
    fig = plt.figure(figsize=(5, 5))

    # labels for the three classes
    labels = ['Positive', 'Neutral', 'Negative']

    # Sizes for each slide
    sizes = []
    for sentiment in labels:
        if sentiment in df_year['sentiment'].unique():
            sizes.append(df_year['sentiment'].value_counts()[sentiment])
        else:
            sizes.append(0)

    # Declare pie chart, where the slices will be ordered and plotted counter-clockwise:
    plt.pie(sizes, labels=labels, \
            autopct=lambda pct: '{:.2f}%\n({:d} reviews)'.format(pct, int(pct/100*df_year.shape[0])), \
            startangle=90)

    # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.axis('equal')  
    
    # title
    plt.title('{} review sentiment distribution\n'.format(year))
    
    # Display the chart
    plt.show()

# %%
for year in range(2002, 2019):
    pie_chart(df, year)

# %% [markdown]
# Bar plots to see trends

# %%
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='year', hue='sentiment', multiple='fill', binwidth=1, stat='probability')
plt.xticks(range(2002,2019))
plt.show()

# %%
# sentiment_perc = df['sentiment'].groupby(df['year']).value_counts(normalize=True).\
#                     rename('percentage').reset_index()

# plt.figure(figsize=(15, 5))
# sns.barplot(x='year', y='percentage', hue='sentiment', data=sentiment_perc)
# plt.show()

# %% [markdown]
# <h2>Hypothesis Testing</h2>

# %% [markdown]
# From the plots above, we can clearly see that the percentage of positive reviews increased from 62% in 2005 to 76% in 2006. We are interested in testing if the changes in the positive review percentage is due to chance. We will select 5% as the significance level α and use **two proportions z-test**, to test our hypothesis that for each year from 2003 to 2018:
#
# **H<sub>0</sub>**: The positive review percentage in the current year is lower than or equal to the previous year, or p<sub>year</sub> ≤ p<sub>year - 1</sub><br>
# **H<sub>1</sub>**: The positive review percentage in the current year is higher the previous year, or p<sub>year</sub> > p<sub>year - 1</sub>

# %%
yearly_sentiment = pd.DataFrame(df.groupby(['year']).size().rename('review_count'))
yearly_sentiment['positive_count'] = df[df.sentiment == 'Positive'].groupby(['year']).size()
yearly_sentiment['positive_pct'] = (yearly_sentiment['positive_count'] / yearly_sentiment['review_count']).round(3)

yearly_sentiment
# Out:
#       review_count  positive_count  positive_pct
# year
# 2002             5               4         0.800
# 2003            19              16         0.842
# 2004            52              36         0.692
# 2005           154              95         0.617
# 2006           326             249         0.764
# 2007          1473            1123         0.762
# 2008          1716            1319         0.769
# 2009          1956            1506         0.770
# 2010          2083            1581         0.759
# 2011          3019            2230         0.739
# 2012          7547            5578         0.739
# 2013         25118           18051         0.719
# 2014         86723           59439         0.685
# 2015        195397          132669         0.679
# 2016        306711          210145         0.685
# 2017        165984          117416         0.707
# 2018         54306           39212         0.722

# %%
from statsmodels.stats.proportion import proportions_ztest

p_value = [None]

for year in range(2002, 2018):
    count = yearly_sentiment.loc[[year+1, year]]['positive_count']
    nobs = yearly_sentiment.loc[[year+1, year]]['review_count']

    stat, pval = proportions_ztest(count, nobs, alternative='larger')
    p_value.append(round(pval, 4))

yearly_sentiment['p_value'] = p_value

yearly_sentiment
# Out:
#       review_count  positive_count  positive_pct  p_value
# year
# 2002             5               4         0.800      NaN
# 2003            19              16         0.842   0.4111
# 2004            52              36         0.692   0.8966
# 2005           154              95         0.617   0.8358
# 2006           326             249         0.764   0.0004
# 2007          1473            1123         0.762   0.5217
# 2008          1716            1319         0.769   0.3387
# 2009          1956            1506         0.770   0.4631
# 2010          2083            1581         0.759   0.7934
# 2011          3019            2230         0.739   0.9498
# 2012          7547            5578         0.739   0.4812
# 2013         25118           18051         0.719   0.9998
# 2014         86723           59439         0.685   1.0000
# 2015        195397          132669         0.679   0.9996
# 2016        306711          210145         0.685   0.0000
# 2017        165984          117416         0.707   0.0000
# 2018         54306           39212         0.722   0.0000

# %%
def highlight_increase(s):
    return ["color: red" if (v > s.iloc[i-1]) & (i > 0) else '' for i, v in enumerate(s)]

def highlight_p(s):
    return ["background: yellow" if v < 0.05 else "" for v in s]

yearly_sentiment.style.apply(highlight_increase, subset=['positive_pct']).apply(highlight_p, subset=['p_value'])
# Out:
# <style  type="text/css" >
#     #T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row1_col2 {
#             color:  red;
#         }    #T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row4_col2 {
#             color:  red;
#         }    #T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row4_col3 {
#             background:  yellow;
#         }    #T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row6_col2 {
#             color:  red;
#         }    #T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row7_col2 {
#             color:  red;
#         }    #T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row14_col2 {
#             color:  red;
#         }    #T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row14_col3 {
#             background:  yellow;
#         }    #T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row15_col2 {
#             color:  red;
#         }    #T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row15_col3 {
#             background:  yellow;
#         }    #T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row16_col2 {
#             color:  red;
#         }    #T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row16_col3 {
#             background:  yellow;
#         }</style><table id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >review_count</th>        <th class="col_heading level0 col1" >positive_count</th>        <th class="col_heading level0 col2" >positive_pct</th>        <th class="col_heading level0 col3" >p_value</th>    </tr>    <tr>        <th class="index_name level0" >year</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0level0_row0" class="row_heading level0 row0" >2002</th>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row0_col1" class="data row0 col1" >4</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row0_col2" class="data row0 col2" >0.800000</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row0_col3" class="data row0 col3" >nan</td>
#             </tr>
#             <tr>
#                         <th id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0level0_row1" class="row_heading level0 row1" >2003</th>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row1_col0" class="data row1 col0" >19</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row1_col1" class="data row1 col1" >16</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row1_col2" class="data row1 col2" >0.842000</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row1_col3" class="data row1 col3" >0.411100</td>
#             </tr>
#             <tr>
#                         <th id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0level0_row2" class="row_heading level0 row2" >2004</th>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row2_col0" class="data row2 col0" >52</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row2_col1" class="data row2 col1" >36</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row2_col2" class="data row2 col2" >0.692000</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row2_col3" class="data row2 col3" >0.896600</td>
#             </tr>
#             <tr>
#                         <th id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0level0_row3" class="row_heading level0 row3" >2005</th>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row3_col0" class="data row3 col0" >154</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row3_col1" class="data row3 col1" >95</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row3_col2" class="data row3 col2" >0.617000</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row3_col3" class="data row3 col3" >0.835800</td>
#             </tr>
#             <tr>
#                         <th id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0level0_row4" class="row_heading level0 row4" >2006</th>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row4_col0" class="data row4 col0" >326</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row4_col1" class="data row4 col1" >249</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row4_col2" class="data row4 col2" >0.764000</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row4_col3" class="data row4 col3" >0.000400</td>
#             </tr>
#             <tr>
#                         <th id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0level0_row5" class="row_heading level0 row5" >2007</th>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row5_col0" class="data row5 col0" >1473</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row5_col1" class="data row5 col1" >1123</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row5_col2" class="data row5 col2" >0.762000</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row5_col3" class="data row5 col3" >0.521700</td>
#             </tr>
#             <tr>
#                         <th id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0level0_row6" class="row_heading level0 row6" >2008</th>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row6_col0" class="data row6 col0" >1716</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row6_col1" class="data row6 col1" >1319</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row6_col2" class="data row6 col2" >0.769000</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row6_col3" class="data row6 col3" >0.338700</td>
#             </tr>
#             <tr>
#                         <th id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0level0_row7" class="row_heading level0 row7" >2009</th>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row7_col0" class="data row7 col0" >1956</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row7_col1" class="data row7 col1" >1506</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row7_col2" class="data row7 col2" >0.770000</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row7_col3" class="data row7 col3" >0.463100</td>
#             </tr>
#             <tr>
#                         <th id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0level0_row8" class="row_heading level0 row8" >2010</th>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row8_col0" class="data row8 col0" >2083</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row8_col1" class="data row8 col1" >1581</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row8_col2" class="data row8 col2" >0.759000</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row8_col3" class="data row8 col3" >0.793400</td>
#             </tr>
#             <tr>
#                         <th id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0level0_row9" class="row_heading level0 row9" >2011</th>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row9_col0" class="data row9 col0" >3019</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row9_col1" class="data row9 col1" >2230</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row9_col2" class="data row9 col2" >0.739000</td>
#                         <td id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0row9_col3" class="data row9 col3" >0.949800</td>
#             </tr>
#             <tr>
#                         <th id="T_dd7978e8_7d40_11eb_b692_5c879cd8c4c0level0_row10" class="ro

# %% [markdown]
# **In year 2006, 2016, 2017 and 2018, the p values from two proportions z tests are statistically significant to reject the null hypothesis. We can conclude that the positive review percentage for these years are higher than their previous years.**

# %%
df.to_csv('data_wrangling.csv',index=False)
